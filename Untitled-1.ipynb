# %%
from datasets import load_dataset

dataset = load_dataset("azminetoushikwasi/cristiano-ronaldo-all-club-goals-stats", use_auth_token=True)
# Out:
# Using custom data configuration azminetoushikwasi--cristiano-ronaldo-all-club-goals-stats-a0623dcc1ee883c9
# Found cached dataset csv (C:/Users/hakan/.cache/huggingface/datasets/azminetoushikwasi___csv/azminetoushikwasi--cristiano-ronaldo-all-club-goals-stats-a0623dcc1ee883c9/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317)
# 100%|██████████| 1/1 [00:00<00:00, 335.36it/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['Unnamed: 0', 'Goal_no', 'Season', 'Competition', 'Matchday', 'Venue', 'Team', 'Opponent', 'Result', 'Position', 'Minute', 'At_score', 'Type_of_goal'],
#         num_rows: 698
#     })
# })

# %%
df = dataset['train'].to_pandas()

# %%
df
# Out:
#      Unnamed: 0  Goal_no Season                Competition      Matchday  \
# 0             0        1    2/3              Liga Portugal             6
# 1             1        2    2/3              Liga Portugal             6
# 2             2        3    2/3              Liga Portugal             8
# 3             3        4    2/3  TaÃ§a de Portugal Placard  Fourth Round
# 4             4        5    2/3  TaÃ§a de Portugal Placard   Fifth Round
# ..          ...      ...    ...                        ...           ...
# 693         693      694  21/22             Premier League            33
# 694         694      695  21/22             Premier League            33
# 695         695      696  21/22             Premier League            34
# 696         696      697  21/22             Premier League            37
# 697         697      698  21/22             Premier League            35
#
#     Venue               Team                 Opponent Result Position Minute  \
# 0       H        Sporting CP            Moreirense FC    3:0       LW     34
# 1       H        Sporting CP            Moreirense FC    3:0     None   90+5
# 2       A        Sporting CP              Boavista FC    1:2     None     88
# 3       H        Sporting CP             CD Estarreja    4:1     None     67
# 4       H        Sporting CP  FC Oliveira do Hospital    8:1     None     13
# ..    ...                ...                      ...    ...      ...    ...
# 693     H  Manchester United             Norwich City    3:2       CF     32
# 694     H  Manchester United             Norwich City    3:2       CF     76
# 695     A  Manchester United               Arsenal FC    3:1       CF     34
# 696     H  Manchester United               Chelsea FC    1:1       CF     62
# 697     H  Manchester United             Brentford FC    3:0       CF     61
#
#     At_score       Type_of_goal
# 0        2:0           Solo run
# 1        3:0             Header
# 2        1:2  Right-footed shot
# 3        3:0   Left-footed shot
# 4        3:0               None
# ..       ...                ...
# 693      2:0             Header
# 694      3:2   Direct free kick
# 695      2:1   Left-footed shot
# 696      1:1  Right-footed shot
# 697      2:0            Penalty
#
# [698 rows x 13 columns]

# %%
# replace Ã§ with ç 
df['Competition'] = df['Competition'].str.replace('Ã§', 'ç')

df['Competition'] = df['Competition'].str.replace('Italy Cup', 'Coppa Italia')

df['Competition'] = df['Competition'].str.replace('Liga Portugal', 'Primeira Liga')


df['Competition'] = df['Competition'].str.replace('Taça de Portugal Placard', 'Taça de Portugal')

# %%
df
# Out:
#      Unnamed: 0  Goal_no Season       Competition      Matchday Venue  \
# 0             0        1    2/3     Primeira Liga             6     H
# 1             1        2    2/3     Primeira Liga             6     H
# 2             2        3    2/3     Primeira Liga             8     A
# 3             3        4    2/3  Taça de Portugal  Fourth Round     H
# 4             4        5    2/3  Taça de Portugal   Fifth Round     H
# ..          ...      ...    ...               ...           ...   ...
# 693         693      694  21/22    Premier League            33     H
# 694         694      695  21/22    Premier League            33     H
# 695         695      696  21/22    Premier League            34     A
# 696         696      697  21/22    Premier League            37     H
# 697         697      698  21/22    Premier League            35     H
#
#                   Team                 Opponent Result Position Minute  \
# 0          Sporting CP            Moreirense FC    3:0       LW     34
# 1          Sporting CP            Moreirense FC    3:0     None   90+5
# 2          Sporting CP              Boavista FC    1:2     None     88
# 3          Sporting CP             CD Estarreja    4:1     None     67
# 4          Sporting CP  FC Oliveira do Hospital    8:1     None     13
# ..                 ...                      ...    ...      ...    ...
# 693  Manchester United             Norwich City    3:2       CF     32
# 694  Manchester United             Norwich City    3:2       CF     76
# 695  Manchester United               Arsenal FC    3:1       CF     34
# 696  Manchester United               Chelsea FC    1:1       CF     62
# 697  Manchester United             Brentford FC    3:0       CF     61
#
#     At_score       Type_of_goal
# 0        2:0           Solo run
# 1        3:0             Header
# 2        1:2  Right-footed shot
# 3        3:0   Left-footed shot
# 4        3:0               None
# ..       ...                ...
# 693      2:0             Header
# 694      3:2   Direct free kick
# 695      2:1   Left-footed shot
# 696      1:1  Right-footed shot
# 697      2:0            Penalty
#
# [698 rows x 13 columns]

# %%
df.describe()
df = df.drop('Unnamed: 0', axis=1)

# %%
df
# Out:
#      Goal_no Season       Competition      Matchday Venue               Team  \
# 0          1    2/3     Primeira Liga             6     H        Sporting CP
# 1          2    2/3     Primeira Liga             6     H        Sporting CP
# 2          3    2/3     Primeira Liga             8     A        Sporting CP
# 3          4    2/3  Taça de Portugal  Fourth Round     H        Sporting CP
# 4          5    2/3  Taça de Portugal   Fifth Round     H        Sporting CP
# ..       ...    ...               ...           ...   ...                ...
# 693      694  21/22    Premier League            33     H  Manchester United
# 694      695  21/22    Premier League            33     H  Manchester United
# 695      696  21/22    Premier League            34     A  Manchester United
# 696      697  21/22    Premier League            37     H  Manchester United
# 697      698  21/22    Premier League            35     H  Manchester United
#
#                     Opponent Result Position Minute At_score  \
# 0              Moreirense FC    3:0       LW     34      2:0
# 1              Moreirense FC    3:0     None   90+5      3:0
# 2                Boavista FC    1:2     None     88      1:2
# 3               CD Estarreja    4:1     None     67      3:0
# 4    FC Oliveira do Hospital    8:1     None     13      3:0
# ..                       ...    ...      ...    ...      ...
# 693             Norwich City    3:2       CF     32      2:0
# 694             Norwich City    3:2       CF     76      3:2
# 695               Arsenal FC    3:1       CF     34      2:1
# 696               Chelsea FC    1:1       CF     62      1:1
# 697             Brentford FC    3:0       CF     61      2:0
#
#           Type_of_goal
# 0             Solo run
# 1               Header
# 2    Right-footed shot
# 3     Left-footed shot
# 4                 None
# ..                 ...
# 693             Header
# 694   Direct free kick
# 695   Left-footed shot
# 696  Right-footed shot
# 697            Penalty
#
# [698 rows x 12 columns]

# %%
# cluster the goals based on the competition 
df['Competition'].value_counts()
# Out:
# LaLiga                              311
# UEFA Champions League               140
# Premier League                      102
# Serie A                              81
# Copa del Rey                         22
# FA Cup                               13
# FIFA Club World Cup                   7
# EFL Cup                               4
# Supercopa                             4
# Coppa Italia                          4
# Primeira Liga                         3
# Taça de Portugal                      2
# UEFA Super Cup                        2
# Supercoppa Italiana                   2
# UEFA Champions League Qualifying      1
# Name: Competition, dtype: int64

# %%
# if there's a + sign in the minutes, replace it with 90 + the number after the + sign
for i in range(len(df['Minute'])):
    if '+' in df['Minute'][i]:
        if ('90+') in df['Minute'][i]:
            df['Minute'][i] = df['Minute'][i].replace('+', '')
            df['Minute'][i] = 90 +int(df['Minute'][i])
            df['Minute'][i] = df['Minute'][i] - 900
        elif ('45+') in df['Minute'][i]:
            df['Minute'][i] = df['Minute'][i].replace('+', '')
            df['Minute'][i] = 45 +int(df['Minute'][i])
            df['Minute'][i] = df['Minute'][i] - 450
            
    
df['Minute'] = df['Minute'].astype(int)
# Out:
# C:\Users\hakan\AppData\Local\Temp/ipykernel_4304/837626853.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Minute'][i] = df['Minute'][i].replace('+', '')
# C:\Users\hakan\AppData\Local\Temp/ipykernel_4304/837626853.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Minute'][i] = 90 +int(df['Minute'][i])
# C:\Users\hakan\AppData\Local\Temp/ipykernel_4304/837626853.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Minute'][i] = df['Minute'][i] - 900
# C:\Users\hakan\AppData\Local\Temp/ipykernel_4304/837626853.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Minute'][i] = df['Minute'][i].replace('+', '')
# C:\Users\hakan\AppData\Local\Temp/ipykernel_4304/837626853.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Minute'][i] = 45 +int(df['Minute'][i])
# C:\Users\hakan\AppData\Local\Temp/ipykernel_4304/837626853.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Minute'][i] = df['Minute'][i] - 450

# %%
df
# Out:
#      Goal_no Season       Competition      Matchday Venue               Team  \
# 0          1    2/3     Primeira Liga             6     H        Sporting CP
# 1          2    2/3     Primeira Liga             6     H        Sporting CP
# 2          3    2/3     Primeira Liga             8     A        Sporting CP
# 3          4    2/3  Taça de Portugal  Fourth Round     H        Sporting CP
# 4          5    2/3  Taça de Portugal   Fifth Round     H        Sporting CP
# ..       ...    ...               ...           ...   ...                ...
# 693      694  21/22    Premier League            33     H  Manchester United
# 694      695  21/22    Premier League            33     H  Manchester United
# 695      696  21/22    Premier League            34     A  Manchester United
# 696      697  21/22    Premier League            37     H  Manchester United
# 697      698  21/22    Premier League            35     H  Manchester United
#
#                     Opponent Result Position  Minute At_score  \
# 0              Moreirense FC    3:0       LW      34      2:0
# 1              Moreirense FC    3:0     None      95      3:0
# 2                Boavista FC    1:2     None      88      1:2
# 3               CD Estarreja    4:1     None      67      3:0
# 4    FC Oliveira do Hospital    8:1     None      13      3:0
# ..                       ...    ...      ...     ...      ...
# 693             Norwich City    3:2       CF      32      2:0
# 694             Norwich City    3:2       CF      76      3:2
# 695               Arsenal FC    3:1       CF      34      2:1
# 696               Chelsea FC    1:1       CF      62      1:1
# 697             Brentford FC    3:0       CF      61      2:0
#
#           Type_of_goal
# 0             Solo run
# 1               Header
# 2    Right-footed shot
# 3     Left-footed shot
# 4                 None
# ..                 ...
# 693             Header
# 694   Direct free kick
# 695   Left-footed shot
# 696  Right-footed shot
# 697            Penalty
#
# [698 rows x 12 columns]

# %%
# plot the goals based on the competition using plotly

import plotly.express as px
fig = px.scatter(df, x="Minute", y="Competition", color="Competition", size='Minute')


# cut competitions based on what country they're in

countries_ronaldo_played = ['Portugal', 'England', 'Spain', 'Italy']
competitions_pt = ['Primeira Liga', 'Taça de Portugal', 'Supertaça Cândido de Oliveira', 'Taça da Liga', 'Supertaça de Portugal', ]
competitions_eng = ['Premier League', 'FA Cup', 'League Cup', 'Community Shield', 'EFL Cup']
competitions_ita = ['Serie A', 'Coppa Italia', 'Supercoppa Italiana', 'Coppa Italia']
competition_esp = ['LaLiga', 'Copa del Rey', 'Supercopa de España', 'Supercopa de España', 'Supercopa']
competition_european = ['UEFA Super Cup', 'UEFA Champions League', 'UEFA Europa League', 'UEFA Champions League Qualifying', 'UEFA Europa League Qualifying']
df['Country'] = df['Competition'].apply(lambda x: 'Portugal' if x in competitions_pt else ('England' if x in competitions_eng else ('Italy' if x in competitions_ita else ('Spain' if x in competition_esp else ('Europe' if x in competition_european else 'Other')))))

# the other in this case is the FIFA Club World Cup
print(df['Country'].value_counts())

# export the dataframe to a csv file for checking
# df.to_csv('ronaldo_goals.csv')
# Out:
# Spain       337
# Europe      143
# England     119
# Italy        87
# Other         7
# Portugal      5
# Name: Country, dtype: int64

# %%
# plot the goals based on country using mathplotlib


df['Country'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# fig.show()

# %%
# calculate the number of goals based on the type of goal
df['Type_of_goal'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['Minute'].value_counts()
# Out:
# 90     17
# 45     15
# 89     15
# 23     14
# 76     14
#        ..
# 72      2
# 95      2
# 93      2
# 120     1
# 1       1
# Name: Minute, Length: 98, dtype: int64

# %%
#
df['Minute'].astype(int)

df['number_scored_at_that_minute'] = df.groupby('Minute')['Minute'].transform('count')

# %%
df
# Out:
#      Goal_no Season       Competition      Matchday Venue               Team  \
# 0          1    2/3     Primeira Liga             6     H        Sporting CP
# 1          2    2/3     Primeira Liga             6     H        Sporting CP
# 2          3    2/3     Primeira Liga             8     A        Sporting CP
# 3          4    2/3  Taça de Portugal  Fourth Round     H        Sporting CP
# 4          5    2/3  Taça de Portugal   Fifth Round     H        Sporting CP
# ..       ...    ...               ...           ...   ...                ...
# 693      694  21/22    Premier League            33     H  Manchester United
# 694      695  21/22    Premier League            33     H  Manchester United
# 695      696  21/22    Premier League            34     A  Manchester United
# 696      697  21/22    Premier League            37     H  Manchester United
# 697      698  21/22    Premier League            35     H  Manchester United
#
#                     Opponent Result Position  Minute At_score  \
# 0              Moreirense FC    3:0       LW      34      2:0
# 1              Moreirense FC    3:0     None      95      3:0
# 2                Boavista FC    1:2     None      88      1:2
# 3               CD Estarreja    4:1     None      67      3:0
# 4    FC Oliveira do Hospital    8:1     None      13      3:0
# ..                       ...    ...      ...     ...      ...
# 693             Norwich City    3:2       CF      32      2:0
# 694             Norwich City    3:2       CF      76      3:2
# 695               Arsenal FC    3:1       CF      34      2:1
# 696               Chelsea FC    1:1       CF      62      1:1
# 697             Brentford FC    3:0       CF      61      2:0
#
#           Type_of_goal   Country  number_scored_at_that_minute
# 0             Solo run  Portugal                             9
# 1               Header  Portugal                             2
# 2    Right-footed shot  Portugal                             9
# 3     Left-footed shot  Portugal                             8
# 4                 None  Portugal                            11
# ..                 ...       ...                           ...
# 693             Header   England                             8
# 694   Direct free kick   England                            14
# 695   Left-footed shot   England                             9
# 696  Right-footed shot   England                            10
# 697            Penalty   England                             8
#
# [698 rows x 14 columns]

# %%
fig = px.scatter(df, x="Minute", y="Competition", color="Competition", size='number_scored_at_that_minute')


fig.show()
